# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

files_to_clear = ['file1.txt', 'file2.txt', 'file.md',"p_steps.txt"  ,"file_analysis.txt"]

# Loop through each file and clear its contents
for file in files_to_clear:
    with open(file, 'w') as f:
        pass  # Opening the file in write mode 'w' and immediately closing it clears its contents

print("All specified files have been cleared.")

#########section 2
train = df1 = pd.read_csv(r"C:\Users\Yug\OneDrive\Desktop\final_ml_ai_agent\dfcleaned2013to2024complet.csv")


print(f"Train shape: {train.shape}")

##section 3

dataset_description= """ ### **Dataset Summary for Predicting Delhi's Power Demand**

This dataset is designed to predict Delhi's daily power demand using various **weather**, **economic**, **demographic**, and **temporal** features.

- **Target Variable**:  
  - **POWER_DEMAND**: Daily electricity demand in Delhi (in Megawatts).

- **Weather Features**:  
  - **Temperature**: `tempmax`, `tempmin`, `temp` (average), and `temp_range`.  
  - **Feels Like Temperature**: `feelslikemax`, `feelslikemin`, `feelslike`.  
  - **Humidity & Precipitation**: `humidity`, `precip`, `precipprob`, `precipcover`.  
  - **Wind & Pressure**: `windspeed`, `sealevelpressure`.  
  - **Conditions**: Weather status (Clear, Rain, Cloudy).  
  - **Heat Index** and **Temperature-Humidity Interactions**.

- **Economic & Demographic Features**:  
  - **Per Capita Income**, **GSDP**, and their **Growth Rates**.  
  - **Population Estimate** and **Growth Rate**.

- **Temporal Features**:  
  - **Date Components**: `month`, `dayofweek`, `dayofyear`, `weekofyear`.  
  - **Holiday & Weekend Indicators**: `is_holiday`, `is_weekend`.  

These features collectively capture factors influencing power demand, including seasonal patterns, economic activity, and population trends."""

additional_info=f"""   do a basic data analysis   on the dataset  and try to find out the following things
try to use  generate more visuals for understanding of data set do a quick data analysis 

dataset is alredy loded in df1 dont  try to load it again you can use df1 for analysis  
"""
  

user_query="""  do the basic and  quick analysis of dataset """   
     
#section 5
 
head=df1.head
dataset_description=dataset_description +f"here is the some few rows of dataset  {head}" +"\n"  +"===here is some additional information==" + "\n" + additional_info + "\n" + "======this is the query====="+user_query
# Out:
# All specified files have been cleared.
# Train shape: (5779, 38)

# %%
import google.generativeai as genai

###defining llms  using in ai systum



import os


GOOGLE_API_KEY='AIzaSyAmuv_OqSde42EYBShuXxN5pwOrwA5GCzE'
genai.configure(api_key=GOOGLE_API_KEY)
# Create the model
generation_config = {
  "temperature":.4,#low-->for learned pattern,,,high for creativity
  "top_p": 0.4,  #-#Top P - A sampling technique with temperature, called nucleus sampling, where you can control how deterministic the model is.
  "top_k": 114,#The top-k parameter effectively controls the vocabulary size considered during text generation. By setting a specific value for k, users can limit the number of words from which the model can choose.
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}
model = genai.GenerativeModel(
  model_name="gemini-1.5-pro-002",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
)
# chat_session = model.start_chat(
#   history=[
#   ]
# )
# response = chat_session.send_message("")
# print(response.text)

# Create a global counter to track the current API key index
api_index = -1  # Start at -1 so the first call uses index 0

def modl():
    global api_index  # Use the global counter

    import random
    
    # List of API keys
    api = [
        'AIzaSyDfJMH62uTq59tYjNvE9-Lg69W1yz--93Y',
        'AIzaSyDYyLj7J4LbajwugLlKSu-Nzr84iBC3qVA',

    ]


    # Increment the index and wrap around if necessary
    api_index = (api_index + 1) % len(api)
    
    # Assign the API key in sequence
    genai.configure(api_key=api[api_index])
    
    generation_config = {
        "temperature":.3,  # Low for learned pattern, high for creativity
        "top_p": 0.7,      # Nucleus sampling control
        "top_k": 111,       # Limits the number of words for consideration during generation
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    
    print(api[api_index])  # Print the assigned API key for verification
    # mod = genai.GenerativeModel('gemini-exp-1121')
    mod = genai.GenerativeModel('gemini-2.0-flash-exp')
    return mod


# Create a global counter to track the current API key index
api_index = -1  # Start at -1 so the first call uses index 0

def modl2():
    global api_index  # Use the global counter

    import random
    
    # List of API keys
    api = [
        'AIzaSyDfJMH62uTq59tYjNvE9-Lg69W1yz--93Y',
        'AIzaSyDYyLj7J4LbajwugLlKSu-Nzr84iBC3qVA',

    ]


    # Increment the index and wrap around if necessary
    api_index = (api_index + 1) % len(api)
    
    # Assign the API key in sequence
    genai.configure(api_key=api[api_index])
    
    generation_config = {
        "temperature":.3,  # Low for learned pattern, high for creativity
        "top_p": 0.7,      # Nucleus sampling control
        "top_k": 111,       # Limits the number of words for consideration during generation
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    
    print(api[api_index])  # Print the assigned API key for verification
#     mod = genai.GenerativeModel('gemini-1.5-pro-exp-0827')
    mod2 = genai.GenerativeModel('gemini-2.0-flash-exp')
    
    # mod2 = genai.GenerativeModel('gemini-exp-1121')

    return mod2

# %%
data_i=dataset_description
file_2="there is no data present yet it is first iteration"
analysis1=""
analysis2=""
analysis3=""
analysis4=""
analysis5=""
analysis6=""
ana_6 = ""
p_steps="no step generates yet it is first "
stratigy="no past thinking is present as you have to generate intital stratigy to resolve the problem"
env="using kaggel notebook without gpu"

context1="""  
---

### Context for LLM1: Strategy Generation and Optimization

**Role and Purpose:**
LLM1 is the core component responsible for developing and optimizing the entire strategy within the AI system. It plays a crucial role by ensuring the system is guided effectively towards solving the query. Its key responsibilities include:

1. **Generate the Main Strategy:**
   - LLM1 outlines a comprehensive, long-term plan designed to achieve the given objective. This strategy is not just about the immediate steps but also includes a broader view of all tasks required to reach the final goal. 
   - The generated strategy takes into account the complete sequence of steps, anticipating future tasks to ensure a smooth progression through the different phases of problem-solving.
   - LLM1 looks ahead, considering not only the immediate next step but also how each step fits into the overall strategy.

2. **Generate Independent Steps:**
   - LLM1 is also tasked with generating independent, actionable steps that can be executed without needing the output of previous steps. These steps serve as foundational tasks in the process (for example, initial data checks such as `df.head()` or `df.info()`).
   - Each step is clearly defined as part of a larger phase of the project (e.g., data exploration, data cleaning, feature engineering) and is labeled accordingly, such as `Step 1.1`, `Step 1.2`. This labeling helps maintain clarity and organization throughout the project.
   - The independence of these steps is key to keeping the workflow flexible and ensuring that essential tasks are completed efficiently before proceeding to dependent steps.

3. **Dynamic Strategy Optimization:**
   - As new insights and analysis are generated, LLM1 continuously refines and optimizes the strategy. This ensures that the system remains efficient and aligned with its ultimate goal.
   - LLM1 considers feedback from LLM3, which provides analysis and insights from previous steps, and makes adjustments to the strategy as needed.
   - The flexibility of LLM1 allows it to maintain coherence with the original plan while adapting to new information, ensuring the strategy remains dynamic and goal-oriented.
   - Even when new steps are introduced or existing steps are refined, LLM1 ensures the system stays on track, progressing logically and efficiently towards the final goal.

**Inputs to LLM1:**
To generate and optimize the strategy effectively, LLM1 relies on several key inputs:
1. **Previous Thinking and Strategy:** The thought process and strategy generated by LLM1 in prior steps. This allows LLM1 to ensure consistency in its approach and avoid redundant or conflicting strategies.
2. **Complete List of All Previous Steps:** A record of all steps created by LLM1 thus far, enabling it to understand the system's progress and ensure no steps are repeated or overlooked.
3. **File 1 (Dataset Information):** 
   - This file contains detailed information about the dataset, the query being addressed, and initial data checks such as `df.head()` and `df.info()`.
   - File 1 is particularly important in the early stages of strategy generation, as it provides the foundational information needed for LLM1 to begin planning the strategy.
4. **File 2 (Previous Steps and Analysis):** 
   - This file includes code, outputs, and summary analyses from previous steps. It helps LLM1 optimize the strategy by learning from past performance.
5. **Detailed Analysis of the Past Five Steps:** A focused review of the most recent steps in the process, which provides critical insights for refining the ongoing strategy.
6. **Context for LLM1:** The role, responsibilities, and objectives of LLM1 within the system are clearly defined to guide its strategy generation and optimization.

**Outputs from LLM1:**
LLM1 produces two main outputs:
1. **Long-Term Strategy/Overall Thinking:** A detailed plan outlining the system’s approach to solving the query. This includes the sequence of tasks, the rationale behind each step, and an explanation of how the strategy will progress through the different phases of the problem-solving process.
2. **Current Step:** The immediate task or step that needs to be executed next. This step is labeled clearly and described in detail so that it can be passed on to LLM2 for execution.

**Interactions with Other LLMs:**
LLM1 interacts closely with the other components of the AI system:
- **LLM2:** LLM1’s output (the current step) is handed over to LLM2, which converts the step into executable code and runs it.
- **LLM3:** LLM3 analyzes the output generated by LLM2, providing feedback on the success of the step and suggesting adjustments if necessary. LLM1 then incorporates this feedback into its ongoing strategy optimization.

**Example Scenario:**
In an example scenario, LLM1 may decide that the first task is to explore the dataset by examining the first few rows and analyzing the data types (`Step 1.1`). Based on the results from LLM3's analysis of this step, LLM1 may then choose to focus on data cleaning or proceed to feature engineering. LLM1 updates the strategy and long-term plan based on the feedback, ensuring the system stays on the most efficient path towards solving the query.

---

### Detailed Workflow of the System:

- **LLM1: Strategy Generation and Optimization**
   - **Inputs:**
     - Previous strategy and thought process
     - Complete list of all previous steps
     - File 1 (dataset description, query, initial data information)
     - File 2 (code, output, and analysis of previous steps)
     - Detailed analysis of the last five steps
     - Context specific to LLM1
   - **Outputs:**
     - Long-term strategy and overall thinking
     - The current step to be executed
   - **Process:**
     - LLM1 analyzes the inputs to generate a flexible strategy that accounts for both the current needs and the long-term progression of the system.
     - It adjusts the strategy dynamically based on new insights and feedback.

- **LLM2: Code Generation and Execution**
   - **Inputs:**
     - Step generated by LLM1
     - File 1 and File 2
     - Detailed analysis
     - Context specific to LLM2
   - **Outputs:**
     - Generates and executes the code for the current step
   - **Process:**
     - Converts the step from LLM1 into executable code, ensuring that it is implemented correctly.

- **LLM3: Output and Code Analysis**
   - **Inputs:**
     - Output from LLM2
     - File 1 and File 2
     - Detailed analysis
     - Context specific to LLM3
   - **Outputs:**
     - Provides insights and suggestions for strategy adjustments
   - **Process:**
     - Analyzes the code and its output to offer feedback to LLM1, ensuring the strategy remains optimized and aligned with the system's goals.

---

### Detailed Instructions for LLM1:

1. **Review the Previous Strategy Carefully:** Your new strategy should evolve from the previous one. Make changes only where necessary while maintaining consistency with past thinking.
2. **Provide a Detailed Strategy:** Explain all the steps you're considering and the reasoning behind them. Include your thought process for generating the current step and label it clearly as `Current Step = [step name]`.
3. **Communicate with LLM2 and LLM3 When Needed:** If there are important considerations for LLM2 (regarding code execution) or LLM3 (regarding analysis), include these in your output.
4. **Focus on Completing Phases Efficiently:** Avoid generating too many steps within a single phase. For example, don’t generate numerous steps for data exploration. Your strategy should focus on logical steps that lead towards completion rather than elongating any particular phase unnecessarily.
5. **Maintain the Role of an Advanced Data Scientist:** Always consider the broader picture, ensuring your strategy leads to a solution rather than getting bogged down in minute details for too long.

---

This version retains the length and depth of your original content while enhancing clarity, expressiveness, and grammatical accuracy for easier comprehension by any LLM. 
"""
prompt1= f"""{context1}

So, I believe you now have a clear understanding of what is going on and your role as LLM1. Let me provide you with the key inputs that have been shared with you so far:

1. **File1:** This contains the initial dataset information along with the main user query, and sometimes additional knowledge, which in this case is: {data_i}.
2. **Past Strategy:** Here is the previous strategy or thought process that has been followed: {stratigy}.
3. **List of Previous Steps:** These are the steps you previously generated, all of which have already been processed. Do not regenerate or repeat these steps: {p_steps}.
4. **File2:** This is critical for your strategy generation. It contains the code, output, and analysis of past steps, and it is essential for you to read this for better strategy optimization: {file_2}.

"""

# model1=modl()
# response = model1.generate_content(peompt1)
# llm1_op=response.text
# stratigy=llm1_op

# print(response.text)


context2= """
---

### **Context Overview:**

You are **LLM2**, an essential part of a multi-LLM system designed to handle complex data analysis tasks. The system consists of multiple LLMs, each with a specific role:

1. **LLM1**: Generates the overall strategy, including both long-term thinking and actionable steps.
2. **LLM2 (Your Role)**: Translates the strategy generated by LLM1 into executable code, executes the code, and manages outputs.
3. **LLM3**: Analyzes the code and output produced by LLM2, offering insights and recommendations for adjusting the strategy.
4. **LLM4**: Focuses on the analysis of visual outputs and intricate data patterns.

Your primary responsibility is to execute each step outlined by LLM1 efficiently while ensuring the data and code are processed accurately without errors.

---

### **Input Information:**

You will work with several key inputs to fulfill your task:

1. **Context**: Understand your role within the system and the responsibilities of the other LLMs.
2. **File Data (`data_i.txt`)**: Contains essential dataset information, user queries, initial dataset details, and other relevant data provided by the user.
3. **P_Step**: A variable storing information on all previously completed steps, helping you avoid redundant actions and maintain an up-to-date workflow.
4. **Strategy (Thinking)**: Generated by LLM1, this strategy includes the current step you must execute (e.g., "Step 1.1: Initial Data Exploration") and long-term strategic insights.
5. **File 2 Data**: A comprehensive record of previous steps, including the code, outputs, and analyses. This ensures you understand the system’s progress and don’t repeat any tasks.
6. **Ana_6 Variable**: Contains a detailed analysis of the last six steps, critical for understanding recent developments and refining the current step.

---

### **Workflow Overview:**

- **Read and Analyze Inputs**:
   - Understand the context of your role and how it fits within the system.
   - Study the dataset details, user queries, and initial data from `data_i.txt`.
   - Focus on the strategy provided by LLM1, especially the current step, and understand its role within the broader strategy.
   - Analyze `File 2 Data` to comprehend previous tasks, processed steps, and the overall progression.
   - Examine the `Ana_6 Variable` to get an analysis of the last six steps.

- **Code Generation and Execution**:
   - Identify the current step from the strategy (e.g., "Step 1.1").
   - Generate the necessary code to accomplish this step.
   - Execute the code and capture the output.
   - If images are generated, ensure multiple images are merged into a single file when applicable.

- **Output Handling**:
   - **Text Output**: Set `llm3 = 1` if the output is textual, directing it to LLM3a.
   - **Image Output**: 
     - Set `llm3 = 2` for image output, directing it to LLM4b.
     - Merge multiple images into one before sending to LLM4b if necessary.

- **LLM3 Variable and Prompt**:
   - Set the `llm3` variable according to the output type.
   - Generate a prompt for LLM3 (either LLM3a or LLM3b) to guide the analysis of the current step.

- **Documentation and Updates**:
   - After completing each step, document:
     - The step number and its details.
     - The code generated.
     - The resulting output.
   - Update `file1.txt` with this information for future reference and for LLM4’s analysis.

---

### **Task Execution**:

- **Data Reading**: Start by reading the provided files: `data_i.txt`, `File 2 Data`, and the `Ana_6 Variable`.
- **Strategy Analysis**: Review the strategy, focusing on the "current step" from LLM1. Identify the step number and its description.
- **Code Generation**: Based on the strategy and prior steps, generate the code for the current task.
- **Execution**: Execute the code and capture the output.
- **Output Classification**: Assign the correct value to `llm3`:
   - `llm3 = 1` for text output.
   - `llm3 = 2` for image output.
   - Set the `state` variable according to the current step (e.g., `state = 1.1`).
- **Documentation**: Record the step details, generated code, and output in `file1.txt`.

---

### **State Variable Declaration**:

- Define the state variable based on the current step you are executing.
- For example, if you are on "Step 1.1," set `state = 1.1`.

---

### **Minimizing Errors**:

- Avoid generating code or explanations that might introduce errors during execution.
- Handle common issues like saving images in the correct format as needed.

---

### **Code Generation Format**:

- **Comments**: Use comments sparingly, only when necessary to clarify the code.
- **Variables**:
   - Set `llm3 = 1` or `llm3 = 2` based on the output type.
   - Define the `state` variable for the current step (e.g., `state = 1.1`).
   - Define the `step` variable to include the step label and description (e.g., `step = "Step 1.4: Analyzing the Statistics of the Numerical Columns"`).
   - Set up the `communication` variable for messages to other LLMs.

---

This prompt equips LLM2 with a clear understanding of its role, inputs, and tasks while ensuring efficient execution of steps. It emphasizes precise code generation, error minimization, and detailed documentation."""


contxt="""To proceed with operations in this system, here's a breakdown of how each LLM would interact based on your "System Overview":

---

### **Step-by-Step Operation**

1. **LLM1 (Strategy Generation)**:
   - **Task**: Create a strategy for the current analysis step.
   - **Action**: Define what the current step is, e.g., "Step 1.1: Data Cleaning."
   - **Output**: Provides the steps, long-term plan, and short-term actionable steps for LLM2 to execute.
   - **Next Step**: Send the generated strategy to LLM2 for implementation.

2. **LLM2 (Code Execution)**:
   - **Task**: Convert LLM1's strategy into Python code.
   - **Action**:
     - Read the strategy generated by LLM1.
     - Write the code for the current step (e.g., cleaning data, building models, etc.).
     - Execute the code and capture the output (such as cleaned datasets, model accuracy, etc.).
   - **Output**: Outputs the result of code execution (e.g., a cleaned dataset or model performance metrics).
   - **Next Step**: Pass the output to LLM3 for analysis.

3. **LLM3 (Output Analysis)**:
   - **Task**: Analyze the results from LLM2.
   - **Action**:
     - Review the output from LLM2 (e.g., analyze accuracy, patterns, or issues).
     - Suggest improvements or refinements to LLM1, such as tuning hyperparameters or cleaning specific data outliers.
   - **Output**: Insightful suggestions to improve the strategy or next step.
   - **Next Step**: Send analysis back to LLM1 for strategy refinement.

---

### **Example:**
Let’s run through an example scenario:

1. **LLM1** defines "Step 1.1: Data Cleaning" as part of its strategy.
2. **LLM2** writes and executes code to clean the data by handling missing values and outliers, then produces a cleaned dataset.
3. **LLM3** analyzes the cleaned dataset and suggests that LLM1 refine the strategy by adding a normalization step in the next phase.

---

You can now perform the operations based on this workflow, where each LLM follows its distinct role and communicates with the others as part of the analysis process. Would you like to simulate one of these steps or dive deeper into a particular aspect?"""

context_2 = f"""Here's the refined context for LLM3a with the added instructions and key change details:

---

### **Context for LLM3a**

You are LLM3a, a vital component of a sophisticated AI system designed to ensure the accuracy and completeness of the data analysis process. Your role involves analyzing the text output from LLM2, evaluating results, and determining necessary adjustments or additional steps required for correctness and completeness.

### **Key Responsibilities:**

1. **Analyze the Text Output:**
   - Review the output generated by LLM2.
   - Identify significant patterns, insights, or anomalies.
   - Assess the relevance and accuracy of the results in relation to the overall strategy.

2. **Check for Necessary Intermediate Steps:**
   - **Scenario:** If you detect that an additional action is required (e.g., handling missing data, correcting inconsistencies), check if the necessary step is already included in the upcoming plan.
   - **Action:** If the step is **not** listed in the upcoming plan, generate an intermediate step labeled appropriately (e.g., **Intermediate Step 1.2.1**). Clearly define and make the step actionable to address the detected issue.
   - **No Action Needed:** If the required step is already included in the plan, no new intermediate step is needed.
   - **Communication:** Send any required messages or suggestions for strategy changes to LLM1, as LLM1 is responsible for strategy design and step definition.

3. **Provide Feedback:**
   - Suggest improvements or adjustments to existing steps.
   - Highlight discrepancies or issues that need addressing.
   - Recommend further analysis or additional steps if necessary.

4. **Documentation:**
   - Record your analysis, suggestions, and any generated intermediate steps in the designated section of File2.

5. **Interpretation (Conclusion):**
   - Provide findings or insights from your analysis. For example, if prompted with `df.describe()`, highlight important observations and conclusions.
   - Ensure these insights are considered in the further process extensively.

6. **Avoid Useless Analysis:**
   - Ensure your analysis is relevant and useful. Avoid unnecessary details that do not contribute to the current task.

### **Instructions for Generating Intermediate Steps:**

- **Step Generation Criteria:** Generate an intermediate step only if it’s essential for the task's correctness and completeness and isn’t already included in the strategy.
- **Example:** If you find missing values in a DataFrame and there’s no step addressing this, create an intermediate step (e.g., **Intermediate Step 1.2.1** to handle missing values).

### **Error Handling for Image Generation:**

- **Error:** `TypeError: Could not create Blob, expected Blob, dict or an Image type(PIL.Image.Image or IPython.display.Image). Got a: <class 'matplotlib.figure.Figure'>`
- **Solution:** Call `plt.savefig('task_2_1_output.png')` directly after `plt.tight_layout()`. This ensures the plot is generated and ready to be saved before the `savefig` command.

**Key Change:**

- **Explanation:** `plt.savefig()` should be called after plotting commands to ensure the plot is created and saved correctly. Use `plt.tight_layout()` to adjust spacing before saving the figure.

### **Strategy Communication:**

- **Dynamic Strategy:** Be aware that the strategy from LLM1 can change. If you have suggestions for strategy modifications, communicate them to LLM1 for consideration.

---

This refined context ensures that LLM3a has clear responsibilities and instructions for analyzing output, generating necessary steps, handling errors, and communicating with other LLMs for a seamless data analysis process.
**Explanation:**

* **`plt.figure()` creates a figure object.** This object is like a container for your plots.
* **`plt.subplot()` creates axes within the figure.** These are the areas where your plots are drawn.
* **`plt.hist()` and `plt.boxplot()` generate the actual plots.**
* **`plt.tight_layout()` adjusts the spacing to prevent overlapping.**
* **`plt.savefig()` saves the entire figure containing the generated plots as an image.**

By calling `plt.savefig()` after the plotting commands, you ensure that the plot is created and ready to be saved as an image.

you also get the stratigy (which is dynamic and can be changed for by the llm1 so if you want to to suggest for the change in stratigy then do so )

{contxt}
"""



context_3= f"""Here’s the refined prompt for LLM3b:

---

**Prompt for LLM3b:**

You are LLM3b, responsible for analyzing the visual outputs (images) generated by previous steps in the data analysis process. Your role is to thoroughly examine these images, identify any significant visual patterns, correlations, anomalies, or trends, and provide a detailed analysis that supports or challenges the objectives outlined in the strategy plan.

### **Input:**

- **Context:** Background information on the task and its current progress.
- **File1:** Contains the strategy plan and executable steps.
- **File2:** Contains the previous step's code, its output (including images), and analysis by LLM3, as well as the current step's code and output.

### **Tasks:**

#### **Analyze the Visual Output:**

1. **Examine Images:** Carefully review the images generated in the current step to identify key visual patterns, trends, correlations, or outliers.
2. **Evaluate Relevance:** Assess the relevance of these visual patterns to the overall strategy plan, determining whether they support or diverge from expected outcomes.

#### **Provide Feedback:**

1. **Insights:** Offer insights on how the visual data aligns with or challenges the objectives of the strategy plan.
2. **Modifications:** Suggest any necessary modifications to the strategy or analysis approach based on your visual assessment.
3. **Additional Visualizations:** Recommend additional visualizations if they could further clarify or enhance the understanding of the data.

#### **Documentation:**

- **Record Analysis:** Document your findings, insights, and recommendations for future visual analysis in the designated section of File2.

### **Interpretation (Conclusion):**

- **Analysis Output:** Provide conclusions from your visual analysis. For example, if analyzing a scatter plot, describe any observed relationships (e.g., "As feature on the horizontal axis increases, the feature on the vertical axis decreases").
- **Consideration:** Ensure that these findings are considered in the subsequent analysis steps.

### **Additional Notes:**

- **Dynamic Strategy:** Be aware that the strategy from LLM1 can change. If you believe modifications to the strategy are necessary based on your visual analysis, communicate these suggestions to LLM1.
- **Avoid Useless Analysis:** Ensure your analysis is relevant and actionable. Avoid including unnecessary details that do not contribute to the current task.

This prompt ensures that LLM3b thoroughly evaluates visual outputs in alignment with the strategy plan, suggests improvements or additional visualizations as needed, and properly documents its analysis.

---

This prompt provides a clear and structured approach for LLM3b to analyze visual outputs, ensuring that it contributes effectively to the data analysis process.

. **interpretation(conclusion) :**
   -in analysis   you must have to  output the thing that you find and conclude from the analysis in case of EDA,  it is very important 
   >>>for example you are inputed with scatter plot of two features and find that   as feature at horizontal axis incres feature at vertical axis decreases
   >>and you have to consider that analysis in further process extensiveley
. ** dont give usless thing in analysis 
   
you also get the stratigy (which is dynamic and can be changed for by the llm1 so if you want to to suggest for the change in stratigy then do so )

This prompt ensures that LLM3b thoroughly evaluates the visual outputs in line with the strategy plan, suggests improvements or additional visualizations as needed, and properly documents its analysis.

{contxt}




"""







#####section 6
env="using kaggel not , very much powerfull computing so generate code accordingley  " 
mm=['AIzaSyC93Gxh05Ggxjtmav-0pm9QtiYKpKWh5ys','AIzaSyD3Vx2rSQrUo_K4cqqU9QEe_xMuUFzEHJk']
hh=0


llm2_learning = """
1. Ideal structure for code generation:

# Step xyz: Description of the step
code for the step

# Variable assignment
llm3 = 1
state = 1.1
step = "Step xyz: Initial Data Exploration"
communication = "Step xyz completed. Please proceed to the next step."
print("Step xyz completed. Please proceed to the next step.")

2. When generating multiple images, always combine them into a single image file and assign it to a variable like `img=combined_image`. This ensures smooth image handling and output management.

3. Communication between LLMs isn't just "step done". It should include thoughtful interaction to enhance the system’s intelligence:
   - Asking questions or requesting information
   - Sharing insights or discussing the next step in the process
   - Providing suggestions, recommendations, or highlighting mistakes
   - Expressing key findings or raising important issues
   
   The communication allows LLMs to work together intelligently, asking questions or giving suggestions based on the current context and previous outputs.4
4 dont forget to assing the img variabel whenever the image output is prisent 
   """
# 4. Always ensure the system learns from each step by capturing reusable patterns or key information. Highlight these learnings within the step or add them as comments for future use, making the process more efficient and smarter over time.

# 5. Hyperparameter tuning should be optimized for minimal computational resources. Keep processing time and memory usage in mind, especially since there are no GPUs and limited resources.
# 6. some times the  module  you use is  not  present  so  whenever  you  get  the  error  no  module or librarey   then install it using !pip install





def cod(code):
    import io
    import sys
    import re

    # Original code snippet as a string
    co = code
    code_snippet = co

    # Clean the code by removing the markdown syntax and unnecessary lines
    cleaned_code = code_snippet.replace('```python', '').replace('```', '')

    # Further clean the code by removing unnecessary print or markdown-like syntax
    cleaned_code = re.sub(r'^\s*(print\(.`\)|\*.*)$', '`', cleaned_code, flags=re.MULTILINE)

    # Store original stdout (standard output)
    old_stdout = sys.stdout
    new_stdout = io.StringIO()

    # Redirect stdout to the new StringIO object to capture output
    sys.stdout = new_stdout

    # Execute the cleaned code within a try block
    try:
        exec(cleaned_code)
    except Exception as e:
        return f"An error occurred: {str(e)}", cleaned_code
    finally:
        # Reset stdout to its original value
        sys.stdout = old_stdout

    # Get the captured output
    op = new_stdout.getvalue()

    # Return the captured output and the cleaned code
    return op, cleaned_code


# Example usage


state=0.0
t=0

er=0

# %%
# it is experimantal block that generate the correct code on  ##############


import time

while True:
    model5=modl2()
    model1 = modl()
    model2 = modl()
    model11 = modl2()
    model4 = modl()

  
    print(">>>>>>>>>>>>>>", t, "<<<<<<<<<<<")
    t = t + 1



    with open('file2.txt', 'r+') as file2:
        file_2 = file2.read()

   
    # Append the state string to file1
    with open("file1.txt", "a") as file:
        file.write("\n" + p_steps+ "\n")
   # Open the file in read mode
    with open('file.md', 'r') as file:
    # Read the contents of the file and store it in a variable
        markdown_content = file.read()

# Now, the variable `markdown_content` contains the data from `file.md`


    peompt1= context1+ "/n   so i think  you now know about what is going on and your role as llm1  " + f"let me give you  the things whis i mentened that those were prompted into you /n ==it is the file1  which contain the initial information of dataset and the main thing user query   and sometimes the additional knowledg {data_i}"   + f"/n /n  here is the stretigy or past thinking {stratigy}"+  f"  /n   it is theh list of previous step that you generate and all of those are been alredy processed so never regenerate or repet thes steps {p_steps}"   +  f"for the knowledg of past steps and their processing in systum which is there code and output   along with there analysis for the better stretigy generation is  is must for you to read this  {file_2}  >>> <<< "
    response = model5.generate_content(peompt1)
    llm1_op=response.text
    stratigy=llm1_op
    print(stratigy)

    # Function to generate code using model1
    def generate_code(error_message=""):
        
        prompt = f"""{context2} >>>>>>>>> /n /n data_i's data  >>>>>>>>>>{data_i}   
/n ====here is the list of all the previous steps that alredy get executed i provide you this so that you can maintain the logical flow

/n =========== here is the main thing that contains the main strategy and thinking of LLM1: {stratigy}. Extract the doable step from here. It is stored in the variable named `current_step`. 

/n /n Some additional instructions from the user: 
0> The name of the dataset is `df1`. 
1> Provide the code so that I can execute it in {env} directly by pasting it. 
2> Don't generate any text without code. If you want to write additional text for LLM3 or anything else, write it in the form of `print('your message')`. 
3> I gave you access to all past code and output, so if you need any of the past code/data, you can access it, except for the first 4 steps. 
>>> I will execute the output you generate directly, so give the correct and executable output. If you want to give some output, give it in the form of `print('your message')`, or if you want to explain something, then also give it in the same way. 
>>> Don't use any symbols that cause errors. The main thing is I will give the executed code to LLM3.
>>> This is a strict instruction: Give the code that can be executed, and only give the code for the step, nothing irrelevant. And I am using {env}, Python.

/n Give code for one step at a time. <<<Important thing: don't give explanations of the code or anything else other than the code. If you want to provide it, use `#` at the start so that it gets commented out. 
>>> Suppose the code you generate will give an image and text on execution. If it produces multiple images, combine them into a single image and specify that combined image in the variable `img=whatever image is`.

>>> Here is file 2 data that contains the previous step's summary, [code, its output, and its summary of analysis from LLM4]. So, if you need to know about any previous executed step or need anything from previous code, check the file and do not assume things.
Check the file if you want to know about any previous step and its output: {file_2}.

/n Here is the analysis of the previous 6 steps:
This is a detailed analysis of the past 6 steps to ensure the coherence of further code generation and you **must check it**. 
{ana_6} 
It will also contain the details of intermediate steps from previous steps and much more information that is required for processing the current step. 
Please also specify `llm4=1` or `llm4=2` in the code.

/n Here is the list of all previous steps along with their description: 
{p_steps}

/n >>>> I also want the system to behave intelligently, so I added a learning file that contains the data which I, as a human, added to make you more intelligent: {llm2_learning}.

/n >>>Important things to remember: 
1> Don't generate any explanation, description, or anything that cannot be executed. 
2> Never repeat the step. 
3> Don't start over again from step 1.1, as you did in previous trials when I tested you. 
4> Always define the step and the detail of the step at the top of the code (use `#` to comment this line). For example: `# Step: 5.1 Identify columns with missing values in df1 and df2`. 

/n>>> Look, I don't have a powerful processor, too much RAM, or any GPU, so please be mindful if you're choosing hyperparameter tuning, as time is important.

/n >>> Issues to avoid: 
You are having a problem processing steps sequentially. Sometimes you process step 5.1 and then suddenly jump to step 3.2, which has already been processed. Please take care of that. 
If you are instructed to reprocess a previous step based on a new step's analysis, then mention it clearly.


"""

        
        
        return prompt



    # Loop until the code executes without errors
    error_occurred = True
    error_message = ""
    original_prompt = ""  # To store the original prompt

    while error_occurred:
        if error_message:
            msg = f"""
I encountered an error while running the code. Here is the error: {error_message}. This occurred in the following code: {code}. Please generate the **correct code only** with no explanation, descriptions, or additional output. Just return the correct code based on this error.

To assist you, I am providing the previous code and outputs in case you need them for context: {markdown_content}. 

Note: 
- The variable `error_var` provides information on how many times this error has occurred. 
here is error_var=={er}
  - If `error_var == 1`, it means this is the second time you are encountering the same issue, so you should **adjust your strategy**.
  - If `error_var == 4`, generate code that indicates there is a persistent issue and future LLMs should consider changing the strategy, or dropping the task if it's unnecessary. For example: 
    `print("The code has run multiple times with errors. {error_message} Please change the strategy or consider dropping this task.")`  print this   seprately    in run whwre error_var is grater that 4  not write aneything else at that time

Current error variable value: `error_var = {er}`

/n 
6. some times the  module  you use is  not  present  so  whenever  you  get  the  error  no  module or librarey   then install it using !pip install
"""


           
            b2 =  msg 
            model3=modl2()
            response = model3.generate_content(b2)
#             response = model4.generate_content(b2)
            code = response.text
            er=er+1
            time.sleep(3)
        else:
            b2 = generate_code(error_message) 
            
            original_prompt = b2  # Store the original prompt

            response = model1.generate_content(b2)
            code = response.text
            time.sleep(3)
        print("Generated code:\n", code)

        try:
            # Attempt to execute the code
            op, code = cod(code)
            exec(code)
            error_occurred = False  # No error, exit the loop
            original_prompt = ""  # Clear the original prompt when task is completed
        except Exception as e:
            # Capture the error and update the prompt with the error message
            error_message = str(e)
            em = code +  "there is a error in this code " + error_message + " don't generate long text"
            
#         pip
            print("Error occurred:\n", error_message)
            time.sleep(5)  # Wait before retrying
    p_steps=p_steps  + "/n========/n" + step
    # Conditional logic for llm4 processing
    if llm3 == 1:
        def llm3a():
            context = context_2
            prompt = f"""Read this file carefully:\n--->{data_i} --->This is the preprompt and context for you.\n{context}\nNow you have to proceed with this step, whose code is -->{code} and that generates the output -->\n{op}\nAnalysis based on the previous steps and objectives.\nThis is the File2 data that contains all the previous step's code, output, and analysis. You can (and should) use this for understanding previous steps.\n{file_2}\nStep to process: Now you have to process the step {step}  /n /n here is the  dynamic stratigy for that llm1 generae at this stage{stratigy} ."""
            return prompt

        b5 = llm3a()
        response = model2.generate_content(b5)
        analysis = response.text
    else:
        def llm3b():
            context = context_3
            prompt = f"Read this file carefully:\n--->{data_i} --->This is the preprompt and context for you.\n{context}\nNow you have to proceed with this step, whose code is -->{code} and that generates the output -->\n{op}\nAnalysis based on the previous steps and objectives.\nThis is the File2 data that contains all the previous step's code, output, and analysis. You can (and should) use this for understanding previous steps.\n{file_2}\nStep to process: Now you have to process the step {step}."
            return prompt
        time.sleep(3)
        p = llm3b()
        response = model11.generate_content([p, img])
        analysis = response.text


    # Write code and output to a markdown file
    with open("file.md", "a") as file:
        file.write("```python\n" + code + "\n```\n")
        if isinstance(op, str):
            file.write("```output for the step is ---->text\n")
            file.write(op)
            file.write("\n```\n\n")
        else:
            op.save(image_path)
            file.write(f"![output image]({image_path})\n")
    if llm3!=1:
        with open("file.md", "a") as f2:
            f2.write(f"![output image]({img})\n")
    
    
    GOOGLE_API_KEY1=mm[hh]
    if hh==0:
        hh=1
    else:
        hh=0
    genai.configure(api_key=GOOGLE_API_KEY1)

    model_sum = genai.GenerativeModel('gemini-1.5-pro-002')
    print(GOOGLE_API_KEY1)
    analysis_f=analysis + """sumarize this in detail   all the important things should be in the sumrey  and sumrey should not exceed 200 words
>>>do not include the code and output of the code in the sumrey of anallysis  of the step     (most important)
>>>always start the sumrey with detailed labling of step no and its info 
>>>  it is must to ad all the variables defines and  aney future step or intermedate step  detail of future step to take  sumarey of analysis ,recomandation 
>>>should not exceed wors limit of 200 words

""" 
    time.sleep(3)
    sumry = model_sum.generate_content(analysis_f)


    
    analysis6=analysis5
    analysis5=analysis4
    analysis4=analysis3
    analysis3=analysis2
    analysis2=analysis1
    analysis1=analysis
    ana_6= analysis1 + "\n" + analysis2 + "\n" +analysis3 + "\n" +analysis4 + "\n" +analysis5 + "\n" +analysis6 + "\n" 
  

    # Append code, output, and analysis to file2
    with open("file2.txt", "a") as file:
        file.write(f"\n=== Code for the step {step}===\n") 
        file.write(code)
        file.write(f"\n=== Output for the step {step} ===\n")
        file.write(op)
        file.write(f"\n=== Analysis for the step {step} ===\n")
        file.write(sumry.text)               
        file.write("\n")  # Add a newline at the end for better readability

    # Wait for 3 seconds before the next execution
    with open("file_analysis.txt", "a+") as file:
        file.write(f"\n=== Analysis for the step {step} ===\n")
        file.write(analysis)
    er=0
    
    time.sleep(3)
# Out:
# AIzaSyDfJMH62uTq59tYjNvE9-Lg69W1yz--93Y
# AIzaSyDYyLj7J4LbajwugLlKSu-Nzr84iBC3qVA
# AIzaSyAKXELhQjcLYSwu_wovpIikbxkjj68p-M0
# AIzaSyC6jAB2sdLLWreO6vvw5YUO9GsKVECa9AY
# AIzaSyBkOFRgjurDa6pkILWYU1yuyL3reQ0_AKM
# >>>>>>>>>>>>>> 8 <<<<<<<<<<<
# Okay, I understand my role as LLM1 and the provided context, including the dataset details, previous steps, and the current query. I also acknowledge the importance of the file 2 which contains code and analysis of previous steps which is very important to make strategy and i read it all.
#
# Based on the previous steps and analysis, here's my updated strategy:
#
# **Long-Term Strategy and Overall Thinking:**
#
# ...
